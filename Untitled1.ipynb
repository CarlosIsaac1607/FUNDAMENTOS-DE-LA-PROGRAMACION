# %% [markdown]
# fundamentos de programacion, tecnologico, isaac, programa que calcula la equivalecia entre masa y energia ( E=m*c**2)

# %%
m = float(input("ingrese la masa en kg"))
c = float(input("ingrese la velocidad en m/s"))
E = m*c**2
print(f"la energia es {E:.2f}")
# Out:
# ingrese la masa en kg2
# ingrese la velocidad en m/s6
# la energia es 72.0
